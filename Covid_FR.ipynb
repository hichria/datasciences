# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import TimestampedGeoJson

# %%
date = '25-03-19'
df0 = pd.read_csv("data/FR/covid-19_dataset_"+date+".csv", sep =",")
covid_data = df0.tail(1)
covid_data = covid_data.drop(["Date"], axis = 1)
covid_data = covid_data.T
covid_data = covid_data.reset_index()
covid_data.columns = ["Départements", "Contaminés"]
covid_data
# Out:
#                   Départements  Contaminés
# 0         Auvergne-Rhône-Alpes        2093
# 1      Bourgogne-Franche-Comté        1569
# 2                     Bretagne         603
# 3          Centre-Val de Loire         561
# 4                        Corse         225
# 5                    Grand Est        5479
# 6              Hauts-de-France        1753
# 7                Ile-de-France        7660
# 8                    Normandie         688
# 9           Nouvelle-Aquitaine         912
# 10                   Occitanie        1082
# 11            Pays de la Loire         368
# 12  Provence-Alpes-Côte d’Azur        1927
# 13                  Guadeloupe          76
# 14            Saint-Barthélémy           3
# 15                Saint-Martin          11
# 16                      Guyane          28
# 17                  Martinique          66
# 18                     Mayotte          35
# 19                  La Réunion          94

# %%
data_geo = 'data/FR/regions.geojson'

m = folium.Map(location=[46, 2.31], zoom_start=6)
bins = list(covid_data['Contaminés'].quantile([0, 0.25, 0.50, 0.75,0.95, 1]))

m = folium.Map(location=[46, 2.31], zoom_start=6)

folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=covid_data,
    columns=['Départements', 'Contaminés'],
    key_on='properties.name',
    fill_color='YlOrRd',
#     palettes: ‘BuGn’, ‘BuPu’, ‘GnBu’, ‘OrRd’, ‘PuBu’, ‘PuBuGn’, ‘PuRd’, ‘RdPu’, ‘YlGn’, ‘YlGnBu’, ‘YlOrBr’, and ‘YlOrRd’.
    fill_opacity=0.7,
    line_opacity=0.35,
    legend_name='Nombre de contaminés',
    bins = bins,
    highlight = True,
).add_to(m)

folium.LayerControl(position = 'bottomright').add_to(m)
m.save('Covid_FR.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
